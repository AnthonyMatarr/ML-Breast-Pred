# %% [markdown]
# # Clean Data
#
# Merge dataframes, subset columns, create new columns

# %% [markdown]
# ## Set Up
#
# Import packages/libraries and data

# %%
import sys
import os

sys.path.append(os.path.abspath("../"))
from src.config import BASE_PATH
from src.data_utils import import_raw_data_dict, get_feature_lists

from src.clean_filter import merge_dfs
import pandas as pd
import numpy as np
import warnings

# %% [markdown]
# ## Merge DFs
#
# Must clean up column names and ensure all desired variables are present

# %%
data_path = BASE_PATH / "data" / "raw" / "cpt_filtered"
data_dict = import_raw_data_dict(data_path)
combined_df_no_codes, combined_df_w_codes = merge_dfs(
    data_dict, include_cpt=True, expcted_rows=94, verbose=False
)

# %%
replace_dict = {
    "SEX": {
        "male": 0,
        "female": 1,
        "nan": pd.NA,
        "NULL": pd.NA,
        "non-bi": pd.NA,  # removed later
        "non-binary": pd.NA,  # removed later
        "None": None,
    },
    "RACE_NEW": {
        "Unknown/Not Reported": "otherUnknown",
        "Unknown": "otherUnknown",
        "nan": "otherUnknown",
        "Native Hawaiian or Other Pacific Islander": "Native Hawaiian or Pacific Islander",
        "Asian,Some Other Race": "otherUnknown",
        "Native Hawaiian or Pacifi": "Native Hawaiian or Pacific Islander",
        "American Indian or Alaska": "American Indian or Alaska Native",
        "White,Black or African American": "otherUnknown",
        "White,Asian": "otherUnknown",
        "White,Some Other Race": "otherUnknown",
        "Race combinations with low frequency": "otherUnknown",
        "Native Hawaiian or Other Pacific Islander,Asian": "otherUnknown",
        "White,American Indian or Alaska Native": "otherUnknown",
        "White,Native Hawaiian or Other Pacific Islander": "otherUnknown",
        "Black or African American,American Indian or Alaska Native": "otherUnknown",
        "White,Native Hawaiian or Other Pacific Islander,As": "otherUnknown",
        "White,Native Hawaiian or Other Pacific Islander,Asian": "otherUnknown",
        "Black or African American,American Indian or Alask": "otherUnknown",
        "Black or African American,Asian,Some Other Race": "otherUnknown",
        "White,Unknown/Not Reported": "otherUnknown",
        "Race combinations with low frequency": "otherUnknown",
        "NULL": "otherUnknown",
        "Some Other Race": "otherUnknown",
        "Middle Eastern or North African": "otherUnknown",
        "White,Hispanic or Latino": "otherUnknown",
        "White,Middle Eastern or North African": "otherUnknown",
        "Hispanic or Latino": "otherUnknown",
        "Black or African American,Hispanic or Latino": "otherUnknown",
        "Hispanic or Latino,Some Other Race": "otherUnknown",
        "Black or African American,Middle Eastern or North African": "otherUnknown",
    },
    "ETHNICITY_HISPANIC": {
        "N": "noUnknown",
        "U": "noUnknown",
        "Y": "Yes",
        "No": "noUnknown",
        "Unknown": "noUnknown",
        "nan": "noUnknown",
        "Unk": "noUnknown",
        "NULL": "noUnknown",
        "None": "noUnknown",
    },
    "ANESTHES": {
        "Monitored Anesthesia Care": "MAC",
        "MAC/IV Sedation": "MAC",
        "Local": "otherUnknown",
        "Regional": "otherUnknown",
        "Other": "otherUnknown",
        "Spinal": "otherUnknown",
        "Epidural": "otherUnknown",
        "None": "otherUnknown",
        "Unknown": "otherUnknown",
        "nan": "otherUnknown",
        "NULL": "otherUnknown",
        None: "otherUnknown",
    },
    "SURGSPEC": {
        "General Surgery": "General",
        "Gynecology": "otherUnknown",
        "Vascular": "otherUnknown",
        "Otolaryngology (ENT)": "otherUnknown",
        "Neurosurgery": "otherUnknown",
        "Orthopedics": "otherUnknown",
        "Thoracic": "otherUnknown",
        "Urology": "otherUnknown",
        "Cardiac Surgery": "otherUnknown",
        "Obstetrics": "otherUnknown",
        "Interventional Radiologist": "otherUnknown",
        "Other": "otherUnknown",
    },
    "DIABETES": {"NON-INSULIN": "ORAL"},
    "SMOKE": {"nan": None},
    "ASCITES": {"Ye": "Yes"},
    "HXCHF": {"Ye": "Yes"},
    "HYPERMED": {"nan": None},
    "DIALYSIS": {"Ye": "Yes"},
    "DISCANCR": {"nan": None},
    "URGENCY": {
        "Urgent": 1,  # urgent
        "Emergent": 1,  # urgent
        "Yes": 1,  # urgent
        "Elective": 0,  # elective
        "No": 0,  # elective
        "NUL": None,
        "nan": None,
    },
    "INOUT": {
        "Inpatient": 1,
        "Outpatient": 0,
    },
    # group class 4 and 5
    "ASACLAS": {  # Will impute these NAs later
        "None assigned": None,
        "nan": None,
        "None": None,
        "1-No Disturb": 1,
        "2-Mild Disturb": 2,
        "3-Severe Disturb": 3,
        "4-Life Threat": 4,
        "5-Moribund": 4,
    },
    "YRDEATH": {
        "-99": "No",
        "-99.0": "No",
    },
    "SUPINFEC": {
        "No Complication": "No",
        "Superficial Incisional SSI": "Yes",
    },
    "WNDINFD": {
        "No Complication": "No",
        "Deep Incisional SSI": "Yes",
    },
    "WNDINF": {
        "Deep Incisional SSI": "Yes",
    },
    "ORGSPCSSI": {"No Complication": "No", "Organ/Space SSI": "Yes"},
    "DEHIS": {
        "No Complication": "No",
        "Wound Disruption": "Yes",
        "0": "No",
        "1": "Yes",
        "2": "Yes",
    },
    "OUPNEUMO": {"No Complication": "No", "Pneumonia": "Yes"},
    "REINTUB": {
        "No Complication": "No",
        "Unplanned Intubation": "Yes",
        "Unplanned Intub": "Yes",
    },
    "PULEMBOL": {"No Complication": "No", "Pulmonary Embolism": "Yes"},
    "FAILWEAN": {"No Complication": "No", "On Ventilator greater than 48 Hours": "Yes"},
    "URNINFEC": {"No Complication": "No", "Urinary Tract Infection": "Yes"},
    "CNSCVA": {"No Complication": "No", "Stroke/CVA": "Yes"},
    "CDARREST": {
        "No Complication": "No",
        "Cardiac Arrest Requiring CPR": "Yes",
        "Cardiac Arrest": "Yes",
    },
    "CDMI": {
        "No Complication": "No",
        "Myocardial Infarction": "Yes",
        "Myocardial Infa": "Yes",
    },
    "OTHBLEED": {
        "No Complication": "No",
        "Transfusions/Intraop/Postop": "Yes",
        "Blood Transfusion": "Yes",
        "Bleeding/Transfusions": "Yes",
    },
    "OTHDVT": {
        "No Complication": "No",
        "DVT Requiring Therapy": "Yes",
        "Venous Thrombosis Requiring Therapy": "Yes",
        "DVT Requiring Therap": "Yes",
    },
    "OTHSYSEP": {"No Complication": "No", "Sepsis": "Yes"},
    "OTHSESHOCK": {"No Complication": "No", "Septic Shock": "Yes"},
    "READ": {  # assume NAs outside of 08-10 are NO (only in 11, 14)
        "nan": "No",
    },
    "UNPLNREAD": {  # assume NAs outside of 08-10 are NO (in all years)
        "nan": "No",
    },
    "DYSPNEA": {  # remove this NA
        "MODERATE EXERTION": "Yes",
        "AT REST": "Yes",
        "nan": pd.NA,  # remove later
    },
    "FNSTATUS2": {
        "Unknown": "otherUnknown",
        "Partially Dependent": "Dependent",
        "Totally Dependent": "Dependent",
        "Partially D": "Dependent",
        "Totally Dep": "Dependent",
    },
    "RENAFAIL": {
        "Ye": "Yes",
    },
    "PRSEPIS": {  # assume NA =No bc no formal "NO" recorded
        "None": "No",
        "nan": "No",
        "SIRS": "Yes",
        "Sepsis": "Yes",
        "Septic Shock": "Yes",
        "Septic": "Yes",
        "NULL": "No",
    },
    "RENAINSF": {
        "No Complication": "No",
        "Progressive Renal Insufficiency": "Yes",
        "Postop  Renal Insufficiency": "Yes",
        "Postop† Renal†Insufficiency": "Yes",
        "Progressive Ren": "Yes",
        "Postop\xa0 Renal\xa0Insufficiency": "Yes",
    },
    "OPRENAFL": {
        "No Complication": "No",
        "Acute Renal Failure": "Yes",
        "Postop Dialysis": "Yes",
        "Acute Renal Fai": "Yes",
    },
    "DISCHDEST": {
        # "Home": "Home",
        "Home/Permanent Residence": "Home",
        # "Unknown_08_10": 78219,
        "Skilled Care, Not Home": "Acute Care",
        "Facility Which was Home": "Home",
        "Separate Acute Care": "Acute Care",
        "Other Facility": "otherUnknown",
        "Rehab": "Acute Care",
        "Unknown": "otherUnknown",
        "Acute Care Hospital": "Acute Care",
        "NULL": "otherUnknown",
        "Unskilled Facility Not Home": "Acute Care",
        "Against Medical Advice (AMA)": "otherUnknown",
        "Expired": "Died",
        "Multi-level Senior Community": "otherUnknown",
        "nan": "otherUnknown",
        "Hospice": "Acute Care",
        "None": "otherUnknown",
        "Unskilled Facility Not": "Acute Care",
    },
    "AGE": {"90+": "90"},
    "HEIGHT": {"-99": pd.NA, "-99.0": pd.NA},
    "WEIGHT": {"-99": pd.NA, "-99.0": pd.NA},
    "TOTHLOS": {"-99": pd.NA},
    "OPTIME": {"-99": pd.NA},
    "PRALBUM": {"-99.0": pd.NA},
    "PRWBC": {"-99.0": pd.NA},
    "PRHCT": {"-99.0": pd.NA},
    "PRPLATE": {"-99": pd.NA, "-99.0": pd.NA},
}
cols_to_impute = [
    "ASACLAS",
    "AGE",
    "HEIGHT",
    "WEIGHT",
    "TOTHLOS",
    "OPTIME",
    "PRALBUM",
    "PRWBC",
    "PRHCT",
    "PRPLATE",
]

na_drop_cols = [
    "SEX",
    "SMOKE",
    "HYPERMED",
    "DISCANCR",
    "URGENCY",
    "DYSPNEA",
]

recon_cols = [
    # Implant based
    "IMMEDIATECPT",
    "DELAYEDCPT",
    "TEINSERTIONCPT",
    "TEEXPANDERCPT",
    # Autologous
    "FREECPT",
    "LATCPT",
    "SINTRAMCPT",
    "SINTRAMSUPERCPT",
    "BITRAMCPT",
    # Adjuunvt & Revision
    "AUGPROSIMPCPT",
    "MASTOCPT",
    "BREASTREDCPT",
    "FATGRAFTCPT",
    "REVRECBREASTCPT",
    "ADJTISTRANSCPT",
    "OTHERRECONTECHCPT",
]
## Misc --> "NPWTCPT",
mast_cols = ["PARTIALCPT", "SUBSIMPLECPT", "RADICALCPT", "MODIFIEDRADICALCPT"]
surg_ind_cols = [
    "CARCINOMAICD",
    "MALIGNANTICD",
    "METASTATICICD",
    "PROPHYLACTICICD",
    "ABBREASTICD",
    "BENIGNICD",
    "INFLOTHERICD",
    "CONGICD",
    "ABSICD",
]

num_cols = [
    "AGE",
    "OPERYR",
    "HEIGHT",
    "WEIGHT",
    "PRALBUM",
    "PRWBC",
    "PRHCT",
    "PRPLATE",
    "OPTIME",
    "TOTHLOS",
]

# %% [markdown]
# ## Clean resulting categorical instances

# %%
df_copy = combined_df_no_codes.copy()
# Replace entries
drop_space_cols = list(replace_dict.keys()) + [
    "HXCOPD",
    "BLEEDDIS",
    "TRANSFUS",
    "VENTILAT",
    "STEROID",
    "WTLOSS",
]
df_copy[drop_space_cols] = (
    df_copy[drop_space_cols].astype(str).apply(lambda x: x.str.strip())
)
df_copy = df_copy.replace(replace_dict)
# Mortality
df_copy["MORTALITY"] = pd.Series(
    np.where(
        (df_copy["YRDEATH"] == "No") & (df_copy["DISCHDEST"] != "Died"), "No", "Yes"
    )
)
df_copy = df_copy.drop("YRDEATH", axis=1)
## Rename cols to remove underscore
df_copy = df_copy.rename(
    columns={
        "ETHNICITY_HISPANIC": "HISPANIC",
        "RACE_NEW": "RACE",
    }
)
# Deal with numerics
df_copy[num_cols] = df_copy[num_cols].apply(pd.to_numeric, errors="coerce")
df_copy = df_copy.dropna(subset=na_drop_cols)
print(f"Length after dropping NAs: {len(df_copy)}")

# %% [markdown]
# Create new cols based on CPT/ICD

# %%
df_copy = df_copy.rename(columns={col: col.upper() for col in df_copy.columns})

# %%
##Lymph Node Surgery
df_copy["NOLYMPH"] = ((df_copy["SNLBCPT"] == "0") & (df_copy["ALNDCPT"] == "0")).astype(
    int
)
######## Timing of Surgery ########
count_of_ones_mast = df_copy[mast_cols].astype(str).ne("0").sum(axis=1)
count_of_ones_recon = df_copy[recon_cols].astype(str).ne("0").sum(axis=1)
df_copy["MASTONLY"] = ((count_of_ones_mast >= 1) & (count_of_ones_recon == 0)).astype(
    int
)
df_copy["MASTRECON"] = ((count_of_ones_mast >= 1) & (count_of_ones_recon >= 1)).astype(
    int
)
df_copy["RECONONLY"] = ((count_of_ones_mast == 0) & (count_of_ones_recon >= 1)).astype(
    int
)
## Create single timing of surgery categorical column
procedure_cols = ["MASTONLY", "MASTRECON", "RECONONLY"]
# Ensure mutually exclusive
assert len(df_copy[procedure_cols].eq(1).sum(axis=1).value_counts()) == 1
# Ensure all patients fall into 1 category
assert df_copy[procedure_cols].eq(1).sum(axis=1).value_counts().keys() == 1
df_copy["SURGTIMINGCPT"] = df_copy[procedure_cols].idxmax(axis=1)
df_copy = df_copy.drop(columns=procedure_cols, axis=1)
######## Surgical Indication (ICD) ########
# Create single surgical indication (ICD) column
## Ensure mutually exclusive
assert len(df_copy[surg_ind_cols].eq(1).sum(axis=1).value_counts()) == 1
assert df_copy[surg_ind_cols].eq(1).sum(axis=1).value_counts().keys() == 1
## Combine
df_copy["SURGINDICD"] = df_copy[surg_ind_cols].idxmax(axis=1)
df_copy = df_copy.drop(columns=surg_ind_cols, axis=1)

# %%
feat_lists = get_feature_lists(df_copy)
num_cols = feat_lists["numerical_cols"]
ord_cols = feat_lists["ordinal_cols"]
nom_cols = feat_lists["nominal_cols"]
bin_cols = feat_lists["binary_cols"]
### Ensure no more NAs in non-numerical cols ###
assert df_copy[nom_cols + bin_cols].isna().sum().sum() == 0

# %% [markdown]
# Make binary cols 0/1

# %%
for col in bin_cols:
    if "Yes" in df_copy[col].unique():
        df_copy[col] = np.where(df_copy[col] == "Yes", 1, 0)
    assert set(df_copy[col].unique()) == set([1, 0])
df_copy[bin_cols] = df_copy[bin_cols].astype(int)

# %% [markdown]
# ## Subset
#
# - All vs cancer patients
# - All vs reconstruction only patients

# %%
def get_cancer(df):
    ## Patients w/ malignant or caricnoma
    df_cancer = (
        df[(df["SURGINDICD"] == "MALIGNANTICD") | (df["SURGINDICD"] == "CARCINOMAICD")]
        .reset_index(drop=True)
        .copy()
    )
    ## Create binary col
    df_cancer = df_cancer.replace(
        {
            "SURGINDICD": {
                "MALIGNANTICD": 1,
                "CARCINOMAICD": 0,
            }
        }
    )
    return df_cancer


df_cancer_all = get_cancer(df_copy)
df_clean_dict = {
    "all": df_copy,
    "cancer": df_cancer_all,
}

# %% [markdown]
# ## Create Target Variables

# %%
outcome_df_dict = {}
outcome_dict = {
    "serious": [
        "CDARREST",  # cardiac arrest
        "CDMI",  # myocaridal
        "OUPNEUMO",  # pneumonia
        # "RENAINSF", #missing 21 --> progressive renal insufficiency --> added later
        "OPRENAFL",  # acute renal failure
        "PULEMBOL",  # PE
        "OTHDVT",  # venous thrombosis
        "UNPLNREOP",  # unplanned reop
        "WNDINFD",  # deep incisional SSI
        "ORGSPCSSI",  # organ space SSI
        "OTHSYSEP",  # post-op sepsis (systemic sepsis is preo-op)
        "REINTUB",  # unplanned intubation
        "URNINFEC",  # UTI
        "DEHIS",  # wound disruption
    ],
    "any": [
        "CDARREST",  # cardiac arrest
        "CDMI",  # myocaridal
        "OUPNEUMO",  # pneumonia
        # "RENAINSF", #missing 21 --> progressive renal insufficiency --> added later
        "OPRENAFL",  # acute renal failure
        "PULEMBOL",  # PE
        "OTHDVT",  # venous thrombosis
        "UNPLNREOP",  # unplanned reop
        "WNDINFD",  # deep incisional SSI
        "ORGSPCSSI",  # organ space SSI
        "OTHSYSEP",  # post-op sepsis (systemic sepsis is preo-op)
        "REINTUB",  # unplanned intubation
        "URNINFEC",  # UTI
        "DEHIS",  # wound disruption
        "SUPINFEC",  # superficial SSI
        "FAILWEAN",  # post-op vent > 48H
        "CNSCVA",  # stroke
    ],
    "pneumo": ["OUPNEUMO"],
    "cardiac_comp": [
        "CDARREST",  # cardiac arrest
        "CDMI",  # myocaridal
    ],
    "vte": ["OTHDVT", "PULEMBOL"],
    "sepsis": [
        "OTHSYSEP",  # post-op sepsis
        "OTHSESHOCK",  # post-op septic shock
    ],
    "ssi": [
        "SUPINFEC",  # superficial SSI
        "WNDINFD",  # deep incisional SSI
        "ORGSPCSSI",  # organ space SSI
    ],
    "uti": ["URNINFEC"],
    "renal": [
        "OPRENAFL",  # acute renal failure
        # "RENAINSF",  # missing 21 --> progressive renal insufficiency--> added later
    ],
    "unplnreop": ["UNPLNREOP"],
    #'read': ["READ"], #NA 08-10
    "mort": ["MORTALITY"],
}

# for cancer_cohort, sub_dict in df_clean_dict.items():
for cancer_cohort, sub_df in df_clean_dict.items():
    print(f"{cancer_cohort}...")
    df_w_outcomes = sub_df.copy()
    for outcome, col_list in outcome_dict.items():
        if outcome == "renal":
            df_w_outcomes["RENAL"] = np.where(
                (df_w_outcomes["OPRENAFL"] == 1) | (df_w_outcomes["RENAINSF"] == "Yes"),
                1,
                0,
            )
        elif len(col_list) > 1:
            for col in col_list:
                assert set(df_w_outcomes[col].unique()) == set(
                    [0, 1]
                ), f"Col: {df_w_outcomes[col].value_counts()}"
            df_w_outcomes[outcome.upper()] = (
                (df_w_outcomes[col_list] == 1).any(axis=1).astype(int)
            )
            if outcome in ["serious", "any"]:
                ## add renainsf
                df_w_outcomes[outcome.upper()] = np.where(
                    (df_w_outcomes[outcome.upper()] == 1)
                    | (df_w_outcomes["RENAINSF"] == "Yes"),
                    1,
                    0,
                )
        else:
            df_w_outcomes = df_w_outcomes.rename(columns={col_list[0]: outcome.upper()})
        event_rate = df_w_outcomes[outcome.upper()].mean()
        print(f"\t\t Outcome: {outcome}")
        print(f"\t\t Event Rate: {event_rate:.2%}")
        print("*" * 30)
    df_w_outcomes["CASEID"] = df_w_outcomes["CASEID"].astype(int).astype(str)
    outcome_df_dict[cancer_cohort] = df_w_outcomes

# %% [markdown]
# ## Export

# %%
for cancer_cohort, outcome_df in outcome_df_dict.items():
    print(f"{cancer_cohort}...")
    x_path = BASE_PATH / f"data/raw/cleaned/NSQIP_mast_combined_{cancer_cohort}.parquet"
    if x_path.exists():
        x_path.unlink()
        warnings.warn(f"Over-writing x data at {x_path}")
    x_path.parent.mkdir(exist_ok=True, parents=True)
    outcome_df.to_parquet(x_path)
    assert x_path.exists()
